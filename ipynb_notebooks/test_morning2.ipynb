# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_hdf('events_data.hdf5','table')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32473067 entries, 0 to 32473066
# Data columns (total 10 columns):
# event_id        int64
# app_id          int64
# is_active       bool
# device_id       int64
# timestamp       datetime64[ns]
# longitude       float64
# latitude        float64
# label_id        object
# category        object
# labels_count    int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(4), object(2)
# memory usage: 2.4+ GB

# %%
df.head(2)
# Out:
#    event_id               app_id is_active            device_id  \
# 0         2  5927333115845830913      True -6401643145415154744
# 1         2 -5720078949152207372     False -6401643145415154744
#
#             timestamp  longitude  latitude                   label_id  \
# 0 2016-05-01 00:54:12     103.65     30.97  [549, 710, 704, 548, 172]
# 1 2016-05-01 00:54:12     103.65     30.97  [721, 704, 548, 302, 303]
#
#                                             category  labels_count
# 0  [Property Industry 1.0, Relatives 1, Property ...             5
# 1  [Personal Effectiveness 1, Property Industry 2...             5

# %%
a = df.groupby(['event_id'])['app_id'].agg(['count'])

# %%
b = df.groupby(['device_id'])['event_id'].agg(['nunique'])

# %%
df[df.device_id==-9221026417907250887].event_id.unique().shape
# Out:
# (42,)

# %%
(b>=8).sum()
# Out:
# nunique    32529
# dtype: int64

# %%
df.event_id.unique().shape
# Out:
# (1488096,)

# %%
b.max()
# Out:
# nunique    11267
# dtype: int64

# %%
c = (df[df.device_id==-9222661944218806987])

# %%
c.event_id.unique()
# Out:
# array([ 118332, 1048506, 1787011, 1909145, 2129003, 2163095, 2404661,
#        3072680])

# %%
c.groupby(['app_id'])['is_active'].agg(['mean','count'])
# Out:
#                           mean  count
# app_id
# -7326028556762203740  1.000000      3
# -1633938282180439957  0.875000      8
# -1496780918078400356  1.000000      1
# -790408166733700925   0.750000      4
#  242515674746466978   1.000000      1
#  628020936226491308   0.500000      6
#  1000519352029378378  0.200000      5
#  4348659952760821294  0.333333      6
#  5927333115845830913  0.400000      5
#  6278190317900024223  1.000000      6
#  8253533661389545512  1.000000      3
#  8557198901083791098  1.000000      8
#  8693964245073640147  0.750000      8

# %%
c[c.app_id==-1496780918078400356]
# Out:
#           event_id               app_id is_active            device_id  \
# 24008960   2404661 -1496780918078400356      True -9222661944218806987
#
#                    timestamp  longitude  latitude         label_id  \
# 24008960 2016-05-01 00:40:57        0.0       0.0  [713, 704, 548]
#
#                                                    category  labels_count
# 24008960  [Services 1, Property Industry 2.0, Industry tag]             3

# %%
d = df[df.app_id==4348659952760821294].groupby(['device_id'])['is_active'].agg(['count'])

# %%
d.ix[-9215722913042087294]
# Out:
# count    25
# Name: -9215722913042087294, dtype: int64

# %%
df[df.app_id==4348659952760821294].groupby(['device_id'])['is_active'].mean()
# Out:
# device_id
# -9222956879900151005    0.812500
# -9222661944218806987    0.333333
# -9222399302879214035    0.000000
# -9221825537663503111    0.411765
# -9221767098072603291    0.833333
# -9221079146476055829    0.913043
# -9221026417907250887    0.407407
# -9220452176650064280    0.000000
# -9220329415676028483    0.000000
# -9220061629197656378    0.000000
# -9218960997324667698    0.166667
# -9218823910602782607    0.000000
# -9218769147970107256    0.000000
# -9218056599942247372    0.666667
# -9217515328051764906    0.000000
# -9217193238265898015    0.000000
# -9215766592714662253    0.000000
# -9215722913042087294    0.000000
# -9215352913819638805    1.000000
# -9214850807520229548    0.000000
# -9213722931755358670    0.900000
# -9213411371629884254    0.000000
# -9212412905070443687    0.880000
# -9212215094473853407    1.000000
# -9211913362970025570    0.022222
# -9211539959417136500    0.000000
# -9210896665715593536    0.000000
# -9210009798393734484    0.714286
# ...

# %%
df[df.app_id==4348659952760821294].groupby(['device_id'])['is_active'].agg(['count'])
# Out:
#                       count
# device_id
# -9222956879900151005     32
# -9222661944218806987      6
# -9222399302879214035      9
# -9221825537663503111     17
# -9221767098072603291      6
# -9221079146476055829     23
# -9221026417907250887     27
# -9220452176650064280      8
# -9220329415676028483     12
# -9220061629197656378     22
# -9218960997324667698      6
# -9218823910602782607     17
# -9218769147970107256      5
# -9218056599942247372      3
# -9217515328051764906      2
# -9217193238265898015      2
# -9215766592714662253      1
# -9215722913042087294     25
# -9215352913819638805      1
# -9214850807520229548      1
# -9213722931755358670     10
# -9213411371629884254      4
# -9212412905070443687     25
# -9212215094473853407      7
# -9211913362970025570     45
# -9211539959417136500      2
# -9210896665715593536     19
# -9210009798393734484     21
# -9209849644716288960     47
# -9209307853420372553      5
# ...                     ...
# ...

# %%
e = df[df.app_id==4348659952760821294]

# %%
e[e.device_id==-9215722913042087294]
# Out:
#           event_id               app_id is_active            device_id  \
# 332034       32478  4348659952760821294     False -9215722913042087294
# 4503932     448260  4348659952760821294     False -9215722913042087294
# 5279271     528512  4348659952760821294     False -9215722913042087294
# 6187070     620885  4348659952760821294     False -9215722913042087294
# 6965321     698575  4348659952760821294     False -9215722913042087294
# 7188668     719871  4348659952760821294     False -9215722913042087294
# 7758722     780041  4348659952760821294     False -9215722913042087294
# 9310763     933625  4348659952760821294     False -9215722913042087294
# 10277377   1030928  4348659952760821294     False -9215722913042087294
# 10474551   1049829  4348659952760821294     False -9215722913042087294
# 10707555   1074097  4348659952760821294     False -9215722913042087294
# 12402702   1241934  4348659952760821294     False -9215722913042087294
# ...

# %%
df.device_id.unique().shape
# Out:
# (60822,)

# %%
f = df.groupby(['app_id','device_id'])['is_active'].agg(['count'])

g = df.groupby(['app_id','device_id'])['is_active'].mean()

i = pd.DataFrame(g)

j = i.unstack('device_id')

h = f.unstack('device_id')

h.fillna(0,inplace=True)

j.fillna(0,inplace=True)

h[h<8]=0

h[h>=8]=1

((h.sum())>0).sum()

j.head()

j.columns = j.columns.droplevel()
h.columns = h.columns.droplevel()

h.sort_index(axis=1,ascending=True,inplace=True)
j.sort_index(axis=1,ascending=True,inplace=True)
h.sort_index(axis=0,ascending=True,inplace=True)
j.sort_index(axis=0,ascending=True,inplace=True)

list(j.columns.values)==list(h.columns.values)

k = csr_matrix(j)
l = csr_matrix(h)
m = k.multiply(l)

n = pd.DataFrame(m.toarray())

n.columns = list(j.columns.values)

n.index = list(j.index.values)

o = csr_matrix(n)

def save_sparse_csr(filename,array):
    np.savez(filename,data = array.data ,indices=array.indices,
             indptr =array.indptr, shape=array.shape )

def load_sparse_csr(filename):
    loader = np.load(filename)
    return csr_matrix((  loader['data'], loader['indices'], loader['indptr']),
                         shape = loader['shape'])
save_sparse_csr('crosstab_device_appid',o)
