# %%
import pandas as pd
import numpy as np
# %matplotlib inline
#import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import LabelEncoder
from scipy.sparse import csr_matrix, hstack
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import StratifiedKFold
from sklearn.metrics import log_loss

# %%
datadir = 'input/'
gatrain = pd.read_csv(os.path.join(datadir,'gender_age_train.csv'),
                      index_col='device_id')
gatest = pd.read_csv(os.path.join(datadir,'gender_age_test.csv'),
                     index_col = 'device_id')
phone = pd.read_csv(os.path.join(datadir,'phone_brand_device_model.csv'))
# Get rid of duplicate device ids in phone
phone = phone.drop_duplicates('device_id',keep='first').set_index('device_id')
events = pd.read_csv(os.path.join(datadir,'events.csv'),
                     parse_dates=['timestamp'], index_col='event_id')
appevents = pd.read_csv(os.path.join(datadir,'app_events.csv'), 
                        usecols=['event_id','app_id','is_active'],
                        dtype={'is_active':bool})
applabels = pd.read_csv(os.path.join(datadir,'app_labels.csv'))

# %%
gatrain['trainrow'] = np.arange(gatrain.shape[0])
gatest['testrow'] = np.arange(gatest.shape[0])

# %%
brandencoder = LabelEncoder().fit(phone.phone_brand)
phone['brand'] = brandencoder.transform(phone['phone_brand'])
gatrain['brand'] = phone['brand']
gatest['brand'] = phone['brand']
Xtr_brand = csr_matrix((np.ones(gatrain.shape[0]), 
                       (gatrain.trainrow, gatrain.brand)))
Xte_brand = csr_matrix((np.ones(gatest.shape[0]), 
                       (gatest.testrow, gatest.brand)))
print('Brand features: train shape {}, test shape {}'.format(Xtr_brand.shape, Xte_brand.shape))
# Out:
# Brand features: train shape (74645, 131), test shape (112071, 131)

# %%
m = phone.phone_brand.str.cat(phone.device_model)
modelencoder = LabelEncoder().fit(m)
phone['model'] = modelencoder.transform(m)
gatrain['model'] = phone['model']
gatest['model'] = phone['model']
Xtr_model = csr_matrix((np.ones(gatrain.shape[0]), 
                       (gatrain.trainrow, gatrain.model)))
Xte_model = csr_matrix((np.ones(gatest.shape[0]), 
                       (gatest.testrow, gatest.model)))
print('Model features: train shape {}, test shape {}'.format(Xtr_model.shape, Xte_model.shape))
# Out:
# Model features: train shape (74645, 1667), test shape (112071, 1667)

# %%
appencoder = LabelEncoder().fit(appevents.app_id)
appevents['app'] = appencoder.transform(appevents.app_id)
napps = len(appencoder.classes_)

# %%
events.head()
# Out:
#                     device_id           timestamp  longitude  latitude
# event_id
# 1           29182687948017175 2016-05-01 00:55:25     121.38     31.24
# 2        -6401643145415154744 2016-05-01 00:54:12     103.65     30.97
# 3        -4833982096941402721 2016-05-01 00:08:05     106.60     29.70
# 4        -6815121365017318426 2016-05-01 00:06:40     104.27     23.28
# 5        -5373797595892518570 2016-05-01 00:07:18     115.88     28.66

# %%
appevents.event_id.unique()
# Out:
# array([      2,       6,       7, ..., 3252937, 3252946, 3252948])

# %%
appevents.event_id.unique().shape
# Out:
# (1488096,)

# %%
appevents.head(2)
# Out:
#    event_id               app_id is_active    app
# 0         2  5927333115845830913      True  15408
# 1         2 -5720078949152207372     False   3384

# %%
events.head(2)
# Out:
#                     device_id           timestamp  longitude  latitude
# event_id
# 1           29182687948017175 2016-05-01 00:55:25     121.38     31.24
# 2        -6401643145415154744 2016-05-01 00:54:12     103.65     30.97

# %%
# -9218939146261660401                               [800, 795, 794, 405]
# -9218836670984150733                               [796, 795, 794, 405]
# -9218699278470272022                                    [713, 704, 548]
# -9218487885271516150                           [714, 704, 548, 44, 104]
# -9218487885267037129       [711, 714, 548, 704, 811, 795, 794, 405, 44]
# -9218487885246804432                                               [44]
# -9218324692096319308                                    [721, 704, 548]
# -9218310540360546691          [405, 730, 756, 777, 782, 787, 788, 1012]
# -9218007467888061518                                    [713, 704, 548]
# -9217702709289243329                                    [721, 704, 548]
# ...                                                                 ...
#  9219980965795711314                                    [713, 704, 548]
#  9220205176760015004                                    [548, 549, 152]
#  9220205219783929990                          [863, 870, 548, 854, 871]
#  9220516008893070913                                    [721, 704, 548]
#  9220581914111522882  [252, 251, 405, 730, 756, 761, 777, 782, 787, ...
#  9220582377071973188                [737, 738, 786, 774, 781, 405, 730]
#  9220582377072041832  [405, 730, 737, 738, 774, 781, 786, 870, 1017,...
#  9220582377072178212  [713, 704, 548, 405, 730, 737, 744, 775, 779, ...
#  9220752705099898783                                    [714, 704, 548]
#  9220759081799407624                               [713, 721, 548, 704]
#  9220934465400977577                               [802, 795, 794, 405]
#  9221047113491315608                               [811, 795, 794, 405]
#  9221227934018371350                               [711, 714, 548, 704]
#  9221416905928937549                               [811, 795, 794, 405]
#  9221416906510267586                                              [975]
#  9221543165002868377                               [800, 795, 794, 405]
#  9221653581903418123                                    [713, 704, 548]
#  9221699163844714144                                    [548, 854, 871]
#  9221975332454256322                                    [714, 704, 548]
#  9222011580033376138                                [710, 704, 548, 13]
#  9222011580033378943                                    [710, 704, 548]
#  9222011580033379320                                    [710, 704, 548]
#  9222072904806798865                                    [713, 704, 548]
#  9222193706838904353                                    [710, 704, 548]
#  9222307926049432405                               [813, 795, 794, 405]
#  9222488106573038706                                              [179]
#  9222542043353102991                                    [714, 704, 548]
#  9222821882765325814                               [813, 795, 794, 405]
#  9223029189880985324                                              [968]
#  9223317927457411432                [714, 704, 548, 813, 795, 794, 405]
#
# [113211 rows x 1 columns]

# %%
label_cat = pd.read_csv(os.path.join(datadir,'label_categories.csv'))

# %%
labelsss = applabels.merge(label_cat,how='left',on='label_id')

# %%
labelsss[labelsss.label_id==704].head()
# Out:
#                     app_id  label_id               category
# 69156  9058148894318981231       704  Property Industry 2.0
# 69157 -5010107147746880097       704  Property Industry 2.0
# 69158  3520983770777613287       704  Property Industry 2.0
# 69159  3317077434980644433       704  Property Industry 2.0
# 69160  9001857150917770908       704  Property Industry 2.0

# %%
#[Cards RPG, game, Tencent, Custom label]
#[796, 795, 794, 405]

# %%
label_cat[label_cat.label_id==714]
# Out:
#      label_id category
# 639       714   1 free

# %%
id_grp = pd.DataFrame(labelsss.groupby(['app_id'])['label_id'].unique())

# %%
category_grp = pd.DataFrame(labelsss.groupby(['app_id'])['category'].unique())

# %%
id_grp.head()
# Out:
#                                                  label_id  \
# app_id
# -9223281467940916832                 [796, 795, 794, 405]
# -9222877069545393219                                [135]
# -9222785464897897681                 [812, 795, 794, 405]
# -9222198347540756780                 [810, 795, 794, 405]
# -9221970424041518544  [714, 704, 548, 813, 795, 794, 405]
#
#                                                                category  \
# app_id
# -9223281467940916832           [Cards RPG, game, Tencent, Custom label]
# -9222877069545393219                          [education outside class]
# -9222785464897897681  [Parkour avoid class, game, Tencent, Custom la...
# -9222198347540756780  [Casual puzzle categories, game, Tencent, Cust...
# -9221970424041518544  [1 free, Property Industry 2.0, Industry tag, ...
#
#                       labels_count
# app_id
# -9223281467940916832             4
# -9222877069545393219             1
# -9222785464897897681             4
# -9222198347540756780             4
# -9221970424041518544             7

# %%
category_grp.head()
# Out:
#                                                                category
# app_id
# -9223281467940916832           [Cards RPG, game, Tencent, Custom label]
# -9222877069545393219                          [education outside class]
# -9222785464897897681  [Parkour avoid class, game, Tencent, Custom la...
# -9222198347540756780  [Casual puzzle categories, game, Tencent, Cust...
# -9221970424041518544  [1 free, Property Industry 2.0, Industry tag, ...

# %%
category_grp.ix[-9221970424041518544]
# Out:
# category    [1 free, Property Industry 2.0, Industry tag, ...
# Name: -9221970424041518544, dtype: object

# %%
pd.options.display.max_colwidth = 50

# %%
id_grp['category'] = category_grp['category']

# %%
cnt = pd.DataFrame(labelsss.groupby(['app_id'])['label_id'].agg(['count']))

# %%
id_grp.head()
# Out:
#                                                  label_id  \
# app_id
# -9223281467940916832                 [796, 795, 794, 405]
# -9222877069545393219                                [135]
# -9222785464897897681                 [812, 795, 794, 405]
# -9222198347540756780                 [810, 795, 794, 405]
# -9221970424041518544  [714, 704, 548, 813, 795, 794, 405]
#
#                                                                category  \
# app_id
# -9223281467940916832           [Cards RPG, game, Tencent, Custom label]
# -9222877069545393219                          [education outside class]
# -9222785464897897681  [Parkour avoid class, game, Tencent, Custom la...
# -9222198347540756780  [Casual puzzle categories, game, Tencent, Cust...
# -9221970424041518544  [1 free, Property Industry 2.0, Industry tag, ...
#
#                       labels_count
# app_id
# -9223281467940916832             4
# -9222877069545393219             1
# -9222785464897897681             4
# -9222198347540756780             4
# -9221970424041518544             7

# %%
id_grp['labels_count'] = cnt['count']

# %%
a.head()
# Out:
#    event_id               app_id is_active    app            device_id  \
# 0         2  5927333115845830913      True  15408 -6401643145415154744
# 1         2 -5720078949152207372     False   3384 -6401643145415154744
# 2         2 -1633887856876571208     False   7620 -6401643145415154744
# 3         2  -653184325010919369      True   8902 -6401643145415154744
# 4         2  8693964245073640147      True  18686 -6401643145415154744
#
#             timestamp  longitude  latitude
# 0 2016-05-01 00:54:12     103.65     30.97
# 1 2016-05-01 00:54:12     103.65     30.97
# 2 2016-05-01 00:54:12     103.65     30.97
# 3 2016-05-01 00:54:12     103.65     30.97
# 4 2016-05-01 00:54:12     103.65     30.97

# %%
df_final = a.merge(id_grp[['label_id','category','labels_count']], how='left',left_on='app_id',right_index=True)

# %%
appevents.shape
# Out:
# (32473067, 3)

# %%
df_final.head()
# Out:
#    event_id               app_id is_active    app            device_id  \
# 0         2  5927333115845830913      True  15408 -6401643145415154744
# 1         2 -5720078949152207372     False   3384 -6401643145415154744
# 2         2 -1633887856876571208     False   7620 -6401643145415154744
# 3         2  -653184325010919369      True   8902 -6401643145415154744
# 4         2  8693964245073640147      True  18686 -6401643145415154744
#
#             timestamp  longitude  latitude  \
# 0 2016-05-01 00:54:12     103.65     30.97
# 1 2016-05-01 00:54:12     103.65     30.97
# 2 2016-05-01 00:54:12     103.65     30.97
# 3 2016-05-01 00:54:12     103.65     30.97
# 4 2016-05-01 00:54:12     103.65     30.97
#
#                                             label_id  \
# 0                          [549, 710, 704, 548, 172]
# 1                          [721, 704, 548, 302, 303]
# 2  [251, 263, 306, 302, 405, 730, 756, 757, 775, ...
# 3  [405, 730, 747, 749, 776, 782, 785, 255, 251, ...
# 4                          [549, 710, 704, 548, 172]
#
#                                             category  labels_count
# 0  [Property Industry 1.0, Relatives 1, Property ...             5
# 1  [Personal Effectiveness 1, Property Industry 2...             5
# 2  [Finance, Debit and credit, unknown, Custom la...            12
# 3  [Custom label, And the Church, Insurance, Lowe...            10
# 4  [Property Industry 1.0, Relatives 1, Property ...             5

# %%
df_final.to_hdf('events_data.hdf5','table')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-180-a4625227bf69> in <module>()
# ----> 1 df_final.to_hdf('events_data.hdf5','table')
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in to_hdf(self, path_or_buf, key, **kwargs)
#    1099
#    1100         from pandas.io import pytables
# -> 1101         return pytables.to_hdf(path_or_buf, key, self, **kwargs)
#    1102
#    1103     def to_msgpack(self, path_or_buf=None, encoding='utf-8', **kwargs):
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/io/pytables.py in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, **kwargs)
#     258         with HDFStore(path_or_buf, mode=mode, complevel=complevel,
#     259                       complib=complib) as store:
# --> 260             f(store)
#     261     else:
#     262         f(path_or_buf)
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/io/pytables.py in <lambda>(store)
#     253         f = lambda store: store.append(key, value, **kwargs)
#     254     else:
# --> 255         f = lambda store: store.put(key, value, **kwargs)
#     256
#     257     if isinstance(path_or_buf, string_types):
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/io/pytables.py in put(self, key, value, format, append, **kwargs)
#     824             format = get_option("io.hdf.default_format") or 'fixed'
#     825         kwargs = self._validate_format(format, kwargs)
# --> 826         self._write_to_group(key, value, append=append, **kwargs)
#     827
#     828     def remove(self, key, where=None, start=None, stop=None):
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/io/pytables.py in _write_to_group(self, key, value, format, index, append, complib, encoding, **kwargs)
#    1262
#    1263         # write the object
# -> 1264         s.write(obj=value, append=append, complib=complib, **kwargs)
#    1265
#    1266         if s.is_table and index:
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/io/pytables.py in write(self, obj, **kwargs)
#    2795         data = obj._data
#    2796         if not data.is_consolidated():
# -> 2797             data = data.consolidate()
#    2798
#    2799         self.attrs.ndim = data.ndim
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in consolidate(self)
#    3271         bm = self.__class__(self.blocks, self.axes)
#    3272         bm._is_consolidated = False
# -> 3273         bm._consolidate_inplace()
#    3274         return bm
#    3275
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in _consolidate_inplace(self)
#    3276     def _consolidate_inplace(self):
#    3277         if not self.is_consolidated():
# -> 3278             self.blocks = tuple(_consolidate(self.blocks))
#    3279             self._is_consolidated = True
#    3280             self._known_consolidated = True
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in _consolidate(blocks)
#    4267     for (_can_consolidate, dtype), group_blocks in grouper:
#    4268         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4269                                       _can_consolidate=_can_consolidate)
#    4270         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4271     return new_blocks
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    4287         # combination of those slices is a slice, too.
#    4288         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 4289         new_values = _vstack([b.values for b in blocks], dtype)
#    4290
#    4291         argsort = np.argsort(new_mgr_locs)
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/pandas/core/internals.py in _vstack(to_stack, dtype)
#    4333
#    4334     else:
# -> 4335         return np.vstack(to_stack)
#    4336
#    4337
#
# /home/Lenovo/anaconda3/lib/python3.5/site-packages/numpy/core/shape_base.py in vstack(tup)
#     228
#     229     """
# --> 230     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     231
#     232 def hstack(tup):
#
# MemoryError:
